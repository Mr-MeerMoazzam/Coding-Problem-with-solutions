# %% [markdown]
# #Problem Description
# Given an array of positive integers arr, return the sum of all possible odd-length subarrays of arr.
#
# A subarray is a contiguous subsequence of the array.

# %%
class Solution(object):
    def sumOddLengthSubarrays(self, arr):
        """
        :type arr: List[int]
        :rtype: int
        """
        n = len(arr)
        ans = 0

        for i in range(n):     
            summ = 0
            for j in range(i, n):
                summ += arr[j] 
                # j - i is the lenght of subarray; check if array is odd to add to sum
                if not (j - i) % 2:
                    ans += summ     
            
        return ans
