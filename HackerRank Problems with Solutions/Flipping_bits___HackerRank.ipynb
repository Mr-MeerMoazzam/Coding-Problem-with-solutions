# %% [markdown]
# #Problem Description
#
# ![flipping bits.png](data:image/png;base64,...)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'flippingBits' function below.
#
# The function is expected to return a LONG_INTEGER.
# The function accepts LONG_INTEGER n as parameter.
#

def flippingBits(n):
    # Write your code here
    
    no_of_zereos = 34-len(bin(n))
    thirty_two_bit_num=no_of_zereos*"0"+bin(n)[2:]
    return int("".join([str(0) if int(i)==1  else '1' for i in thirty_two_bit_num ]),2)
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input().strip())

    for q_itr in range(q):
        n = int(input().strip())

        result = flippingBits(n)

        fptr.write(str(result) + '\n')

    fptr.close()
# Out:
# 1
# 01111111111111111111111111111111
# 32
# 2147483648
