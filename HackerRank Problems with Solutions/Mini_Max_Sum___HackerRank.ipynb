# %% [markdown]
# #Problem Description
# ![minimax_hackerRank.png](data:image/png;base64,...)

# %% [markdown]
# <b>Sample Input</b><br>
#
# 1 2 3 4 5<br>
# <b>Sample Output</b><br>
#
# 10 14

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'miniMaxSum' function below.
#
# The function accepts INTEGER_ARRAY arr as parameter.
#

def miniMaxSum(arr):
    # Write your code here
    arr_sums=[sum(arr[:i]+arr[i+1:]) for i in range(len(arr))]
    print(min(arr_sums),max(arr_sums))
if __name__ == '__main__':

    arr = list(map(int, input().rstrip().split()))

    miniMaxSum(arr)
# Out:
# 1 2 3 4 5
# 10 14
