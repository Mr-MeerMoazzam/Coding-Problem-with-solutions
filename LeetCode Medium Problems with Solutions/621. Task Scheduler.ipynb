# %% [markdown]
# #Problem Description
# Given a characters array tasks, representing the tasks a CPU needs to do, where each letter represents a different task. Tasks could be done in any order. Each task is done in one unit of time. For each unit of time, the CPU could complete either one task or just be idle.
#
# However, there is a non-negative integer n that represents the cooldown period between two same tasks (the same letter in the array), that is that there must be at least n units of time between any two same tasks.
#
# Return the least number of units of times that the CPU will take to finish all the given tasks.

# %%
"""The idea is to schedule all the tasks inside the idle time of the most frequent task if this can be done then the answer will be (mx-1)*(n+1) + c, 
where mx = max frequency , c = count of max frequency
else there won't be any idle gaps and answer will be number of tasks"""
# Out:
# "The idea is to schedule all the tasks inside the idle time of the most frequent task if this can be done then the answer will be (mx-1)*(n+1) + c, \nwhere mx = max frequency , c = count of max frequency\nelse there won't be any idle gaps and answer will be number of tasks"

# %%
class Solution(object):
    def leastInterval(self, tasks, n):
        """
        :type tasks: List[str]
        :type n: int
        :rtype: int
        """
        count1 = Counter(tasks)
        mx = max(count1.values())
        c = list(count1.values()).count(mx)
        return max(len(tasks), (mx-1)*(n+1)+c)
